# %% [markdown]
# # Pre-trained Model Library
#
# **XenonPy.MDL** is a library of pre-trained models that were obtained by feeding diverse materials data on structure-property relationships into neural networks and some other supervised learning algorithms.
#
# XenonPy offers a simple-to-use toolchain to perform **transfer learning** with the given **pre-trained models** seamlessly.
# In this tutorial, we will focus on model querying and retrieving.

# %% [markdown]
# ### useful functions
#
# Run this cell will load some well-used packages such as `numpy`, `pandas`, and so on.
# The running will also import some valuable functions which are written by ourselves.
# There is no magic,  see `samples/tools.ipynb` to know what will be imported.

# %%
# %run tools.ipynb

# %% [markdown]
# ### access pre-trained models with MDL class
#
# We exposed a wide range of APIs to let you query and download our models.
# These APIs basically can be accessed via any HTTP requests.
# For convenience, we implemented some of the most-used APIs and wrapped them into XenonPy.
# All these functions can be accessed using `xenonpy.datatools.MDL`.

# %%
# --- import necessary libraries

from xenonpy.mdl import MDL

# %%
# --- init and check

mdl = MDL()
mdl
# Out:
# MDL(api_key='anonymous.user.key', endpoint='http://xenon.ism.ac.jp/api')

# %% [markdown]
# Noticed that ``mdl`` has optional parameter ``api_key`` and ``endpoint``.
# ``endpoint`` is as it's name point where to fetch data. ``api_key`` is a access token used to validate the authorization and action permissions.
# At this moment, the defaulat key, ``anonymous.user.key`` is the only acceptable option.
# We will open the public registration system when we are prepared.
#
# If everything goes right, we can query models via some keywords.
# Let's say we want to retrieve some models that trained by the inorganic compounds data and can predict the property of volume.
# In this case, we need to feed the parameter `modelset_has` with **Stable inorganic compounds** and the `property_has` with **volume**.
#
# If successful, the calling will return a `pandas.DataFrame` object will as the querying result. This will contains information about what models there are and their downloadable urls. All the available names are listing at https://xenonpy.readthedocs.io/en/latest/features.html#xenonpy-mdl.

# %%
mdl.list_modelsets()()
# Out:
#    deprecated                                           describe  id  \
# 0       False  Models in this set are trained on ~20,000 stab...   1
# 1       False  Models in this set are trained on ~70,000 inor...   2
# 2       False  Quantum-Machine project can be access from htt...   3
# 3       False  PHYSPROP database contains chemical structures...   4
# 4       False  Jean-Claude Bradley’s dataset of Open Melting ...   5
# 5       False  Polymer Genome is an informatics platform for ...   6
#
#                                               name  private
# 0  Stable inorganic compounds in materials project    False
# 1     All inorganic compounds in materials project    False
# 2                                      QM9 Dataset    False
# 3                                 PHYSPROP Dataset    False
# 4   Jean-Claude Bradley Open Melting Point Dataset    False
# 5                           Polymer Genome Dataset    False

# %%
mdl.get_property_detail('inorganic.crystal.efermi')()
# Out:
# {'fullName': '',
#  'name': 'inorganic.crystal.efermi',
#  'symbol': '',
#  'unit': '',
#  'describe': '',
#  'count': 2400}

# %%
mdl.get_modelset_detail(6)()
# Out:
# {'id': 6,
#  'name': 'Polymer Genome Dataset',
#  'describe': 'Polymer Genome is an informatics platform for polymer property prediction and design using machine learning. It can be accessed via https://www.polymergenome.org/.',
#  'deprecated': False,
#  'private': False,
#  'contributors': [],
#  'owner': 'liu.chang',
#  'sampleCode': '',
#  'tags': [],
#  'count': 370}

# %%
# --- query data

mdl('inorgainc', 'band')()
# Out:
#       deprecated            descriptor    id  isRegression    lang  \
# 0          False  xenonpy.compositions  4724          True  python
# 1          False  xenonpy.compositions  4726          True  python
# 2          False  xenonpy.compositions  4729          True  python
# 3          False  xenonpy.compositions  4732          True  python
# 4          False  xenonpy.compositions  4734          True  python
# 5          False  xenonpy.compositions  4736          True  python
# 6          False  xenonpy.compositions  4738          True  python
# 7          False  xenonpy.compositions  4742          True  python
# 8          False  xenonpy.compositions  4744          True  python
# 9          False  xenonpy.compositions  4746          True  python
# 10         False  xenonpy.compositions  4748          True  python
# 11         False  xenonpy.compositions  4750          True  python
# 12         False  xenonpy.compositions  4751          True  python
# 13         False  xenonpy.compositions  4754          True  python
# 14         False  xenonpy.compositions  4756          True  python
# 15         False  xenonpy.compositions  4759          True  python
# 16         False  xenonpy.compositions  4761          True  python
# 17         False  xenonpy.compositions  4763          True  python
# 18         False  xenonpy.compositions  4765          True  python
# 19         False  xenonpy.compositions  4768          True  python
# 20         False  xenonpy.compositions  4770          True  python
# 21         False  xenonpy.compositions  4772          True  python
# 22         False  xenonpy.compositions  4774          True  python
# 23         False  xenonpy.compositions  4776          True  python
# 24         False  xenonpy.compositions  4778          True  python
# 25         False  xenonpy.compositions  4780          True  python
# 26         False  xenonpy.compositions  4782          True  python
# 27         False  xenonpy.compositions  4784          True  python
# 28         False  xenonpy.compositions  4785          True  python
# 29         False  xenonpy.compositions  4788          True  python
# ...          ...                   ...   ...           ...     ...
# 2370       False  xenonpy.compositions  7268          True  python
# 2371       False  xenonpy.compositions  7270          True  python
# 2372       False  xenonpy.compositions  7271          True  python
# 2373       False  xenonpy.compositions  7273          True  python
# 2374       False  xenonpy.compositions  7276          True  python
# 2375       False  xenonpy.compositions  7277          True  python
# 2376       False  xenonpy.compositions  7279          True  python
# 2377       False  xenonpy.compositions  7281          True  python
# 2378       False  xenonpy.compositions  7283          True  python
# 2379       False  xenonpy.compositions  7286          True  python
# 2380       False  xenonpy.compositions  7289          True  python
# 2381       False  xenonpy.compositions  7291          True  python
# 2382       False  xenonpy.compositions  7293          True  python
# 2383       False  xenonpy.compositions  7295          True  python
# 2384       False  xenonpy.compositions  7297          True  python
# 2385       False  xenonpy.compositions  7299          True  python
# 2386       False  xenonpy.compositions  7301          True  python
# 2387       False  xenonpy.compositions  7303          True  python
# 2388       False  xenonpy.compositions  7305          True  python
# 2389       False  xenonpy.compositions  7307          True  python
# 2390       False  xenonpy.compositions  7310          True  python
# 2391       False  xenonpy.compositions  7312          True  python
# 2392       False  xenonpy.compositions  7314          True  python
# 2393       False  xenonpy.compositions  7317          True  python
# 2394       False  xenonpy.compositions  7319          True  python
# 2395       False  xenonpy.compositions  7321          True  python
# 2396       False  xenonpy.compositions  7324          True  python
# 2397       False  xenonpy.compositions  7327          True  python
# 2398       False  xenonpy.compositions  7328          True  python
# 2399       False  xenonpy.compositions  7330          True  python
#
#       maxAbsError  meanAbsError  meanSquareError                     method  \
# 0        4.125291      0.610073         0.870355  pytorch.nn.neural_network
# 1        4.391356      0.572747         0.765702  pytorch.nn.neural_network
# 2        5.243320      0.603243         0.898776  pytorch.nn.neural_network
# 3        4.864137      0.582556         0.830686  pytorch.nn.neural_network
# 4        5.009331      0.621046         0.934543  pytorch.nn.neural_network
# 5        4.293794      0.665161         1.010093  pytorch.nn.neural_network
# 6        4.898829      0.640651         0.961659  pytorch.nn.neural_network
# 7        3.992013      0.550671         0.732546  pytorch.nn.neural_network
# 8        4.784416      0.554728         0.788352  pytorch.nn.neural_network
# 9        4.674271      0.611629         0.875630  pytorch.nn.neural_network
# 10       3.906834      0.580558         0.806119  pytorch.nn.neural_network
# 11      12.428086      0.582455         0.877435  pytorch.nn.neural_network
# 12       4.976136      0.622786         0.904258  pytorch.nn.neural_network
# 13       4.385163      0.614426         0.876923  pytorch.nn.neural_network
# 14       4.076165      0.605333         0.892338  pytorch.nn.neural_network
# 15       4.224774      0.570167         0.797218  pytorch.nn.neural_network
# 16       4.256370      0.604536         0.848831  pytorch.nn.neural_network
# 17       3.793726      0.622188         0.918556  pytorch.nn.neural_network
# 18      13.467704      0.627428         1.019796  pytorch.nn.neural_network
# 19       4.363132      0.561447         0.792104  pytorch.nn.neural_network
# 20       5.200938      0.660836         1.034627  pytorch.nn.neural_network
# 21       4.305627      0.590186         0.828892  pytorch.nn.neural_network
# 22       4.214491      0.587063         0.851162  pytorch.nn.neural_network
# 23      13.011836      0.573683         0.898575  pytorch.nn.neural_network
# 24       4.103242      0.636759         0.926710  pytorch.nn.neural_network
# 25      11.998322      0.595806         0.920895  pytorch.nn.neural_network
# 26       4.962874      0.667842         1.108801  pytorch.nn.neural_network
# 27      13.320510      0.615032         0.985917  pytorch.nn.neural_network
# 28       3.828832      0.613950         0.862349  pytorch.nn.neural_network
# 29       4.736187      0.617181         0.898640  pytorch.nn.neural_network
# ...           ...           ...              ...                        ...
# 2370    14.799088      0.830263         1.393045  pytorch.nn.neural_network
# 2371     4.803988      0.806141         1.312427  pytorch.nn.neural_network
# 2372     5.966774      0.815928         1.344053  pytorch.nn.neural_network
# 2373     5.162119      0.780555         1.242225  pytorch.nn.neural_network
# 2374     6.276423      0.837335         1.405774  pytorch.nn.neural_network
# 2375    14.292475      0.805616         1.372139  pytorch.nn.neural_network
# 2376     6.266368      0.861580         1.425456  pytorch.nn.neural_network
# 2377     6.045371      0.796404         1.252118  pytorch.nn.neural_network
# 2378     6.466585      0.798907         1.289466  pytorch.nn.neural_network
# 2379    14.442913      0.803868         1.317367  pytorch.nn.neural_network
# 2380    13.636310      0.831688         1.430278  pytorch.nn.neural_network
# 2381     5.064427      0.810828         1.363107  pytorch.nn.neural_network
# 2382     6.657248      0.854294         1.422257  pytorch.nn.neural_network
# 2383     4.891337      0.834194         1.360384  pytorch.nn.neural_network
# 2384    15.080177      0.833168         1.449146  pytorch.nn.neural_network
# 2385    12.782896      0.789403         1.300125  pytorch.nn.neural_network
# 2386    14.445248      0.800517         1.367823  pytorch.nn.neural_network
# 2387    15.370270      0.856089         1.445898  pytorch.nn.neural_network
# 2388    14.695131      0.811541         1.378443  pytorch.nn.neural_network
# 2389     4.632049      0.757692         1.175731  pytorch.nn.neural_network
# 2375  inorganic.crystal.band_gap  0.515290             1.171384      0.744388
# 2376  inorganic.crystal.band_gap  0.500453             1.193925      0.729441
# 2377  inorganic.crystal.band_gap  0.554071             1.118981      0.751092
# 2378  inorganic.crystal.band_gap  0.546066             1.135547      0.754113
# 2379  inorganic.crystal.band_gap  0.528186             1.147766      0.741359
# 2380  inorganic.crystal.band_gap  0.478543             1.195942      0.721202
# 2381  inorganic.crystal.band_gap  0.523605             1.167522      0.737751
# 2382  inorganic.crystal.band_gap  0.498138             1.192584      0.719840
# 2383  inorganic.crystal.band_gap  0.508668             1.166355      0.728917
# 2384  inorganic.crystal.band_gap  0.486583             1.203805      0.721418
# 2385  inorganic.crystal.band_gap  0.544555             1.140230      0.752120
# 2386  inorganic.crystal.band_gap  0.537688             1.169540      0.763330
# 2387  inorganic.crystal.band_gap  0.499244             1.202455      0.730722
# 2388  inorganic.crystal.band_gap  0.497278             1.174071      0.726902
# 2389  inorganic.crystal.band_gap  0.561187             1.084311      0.758034
# 2390  inorganic.crystal.band_gap  0.539621             1.105638      0.755132
# 2391  inorganic.crystal.band_gap  0.491311             1.193763      0.724095
# 2392  inorganic.crystal.band_gap  0.518362             1.153245      0.733867
# 2393  inorganic.crystal.band_gap  0.548196             1.137130      0.749923
# 2394  inorganic.crystal.band_gap  0.537841             1.154005      0.750675
# 2395  inorganic.crystal.band_gap  0.529420             1.146282      0.745228
# 2396  inorganic.crystal.band_gap  0.527005             1.167815      0.742668
# 2397  inorganic.crystal.band_gap  0.517920             1.174027      0.746764
# 2398  inorganic.crystal.band_gap  0.530406             1.144697      0.737474
# 2399  inorganic.crystal.band_gap  0.523822             1.160093      0.746871
#
#       succeed  transferred
# 0        True        False
# 1        True        False
# 2        True        False
# 3        True        False
# 4        True        False
# 5        True        False
# 6        True        False
# 7        True        False
# 8        True        False
# 9        True        False
# 10       True        False
# 11       True        False
# 12       True        False
# 13       True        False
# 14       True        False
# 15       True        False
# 16       True        False
# 17       True        False
# 18       True        False
# 19       True        False
# 20       True        False
# 21       True        False
# 22       True        False
# 23       True        False
# 24       True        False
# 25       True        False
# 26       True        False
# 27       True        False
# 28       True        False
# 29       True        False
# ...       ...          ...
# 2370     True        False
# 2371     True        False
# 2372     True        False
# 2373     True        False
# 2374     True        False
# 2375     True        False
# 2376     True        False
# 2377     True        False
# 2378     True        False
# 2379     True        False
# 2380     True        False
# 2381     True        False
# 2382     True        False
# 2383     True        False
# 2384     True        False
# 2385     True        False
# 2386     True        False
# 2387     True        False
# 2388     True        False
# 2389     True        False
# 2390     True        False
# 2391     True        False
# 2392     True        False
# 2393     True        False
# 2394     True        False
# 2395     True        False
# 2396     True        False
# 2397     True        False
# 2398     True        False
# 2399     True        False
#
# [2400 rows x 18 columns]

# %%
# --- query data

query = mdl(
    modelset_has="stable",  # sub string in the name of modelset
    property_has="band_gap", # substring for property name 
)

# %%
query()
# Out:
#       deprecated            descriptor    id  isRegression    lang  \
# 0          False  xenonpy.compositions  4724          True  python
# 1          False  xenonpy.compositions  4726          True  python
# 2          False  xenonpy.compositions  4729          True  python
# 3          False  xenonpy.compositions  4732          True  python
# 4          False  xenonpy.compositions  4734          True  python
# 5          False  xenonpy.compositions  4736          True  python
# 6          False  xenonpy.compositions  4738          True  python
# 7          False  xenonpy.compositions  4742          True  python
# 8          False  xenonpy.compositions  4744          True  python
# 9          False  xenonpy.compositions  4746          True  python
# 10         False  xenonpy.compositions  4748          True  python
# 11         False  xenonpy.compositions  4750          True  python
# 12         False  xenonpy.compositions  4751          True  python
# 13         False  xenonpy.compositions  4754          True  python
# 14         False  xenonpy.compositions  4756          True  python
# 15         False  xenonpy.compositions  4759          True  python
# 16         False  xenonpy.compositions  4761          True  python
# 17         False  xenonpy.compositions  4763          True  python
# 18         False  xenonpy.compositions  4765          True  python
# 19         False  xenonpy.compositions  4768          True  python
# 20         False  xenonpy.compositions  4770          True  python
# 21         False  xenonpy.compositions  4772          True  python
# 22         False  xenonpy.compositions  4774          True  python
# 23         False  xenonpy.compositions  4776          True  python
# 24         False  xenonpy.compositions  4778          True  python
# 25         False  xenonpy.compositions  4780          True  python
# 26         False  xenonpy.compositions  4782          True  python
# 27         False  xenonpy.compositions  4784          True  python
# 28         False  xenonpy.compositions  4785          True  python
# 29         False  xenonpy.compositions  4788          True  python
# ...          ...                   ...   ...           ...     ...
# 1170       False  xenonpy.compositions  7019          True  python
# 1171       False  xenonpy.compositions  7021          True  python
# 1172       False  xenonpy.compositions  7022          True  python
# 1173       False  xenonpy.compositions  7024          True  python
# 1174       False  xenonpy.compositions  7025          True  python
# 1175       False  xenonpy.compositions  7027          True  python
# 1176       False  xenonpy.compositions  7030          True  python
# 1177       False  xenonpy.compositions  7031          True  python
# 1178       False  xenonpy.compositions  7033          True  python
# 1179       False  xenonpy.compositions  7034          True  python
# 1180       False  xenonpy.compositions  7036          True  python
# 1181       False  xenonpy.compositions  7038          True  python
# 1182       False  xenonpy.compositions  7040          True  python
# 1183       False  xenonpy.compositions  7042          True  python
# 1184       False  xenonpy.compositions  7043          True  python
# 1185       False  xenonpy.compositions  7045          True  python
# 1186       False  xenonpy.compositions  7047          True  python
# 1187       False  xenonpy.compositions  7049          True  python
# 1188       False  xenonpy.compositions  7051          True  python
# 1189       False  xenonpy.compositions  7053          True  python
# 1190       False  xenonpy.compositions  7054          True  python
# 1191       False  xenonpy.compositions  7056          True  python
# 1192       False  xenonpy.compositions  7057          True  python
# 1193       False  xenonpy.compositions  7059          True  python
# 1194       False  xenonpy.compositions  7061          True  python
# 1195       False  xenonpy.compositions  7063          True  python
# 1196       False  xenonpy.compositions  7065          True  python
# 1197       False  xenonpy.compositions  7067          True  python
# 1198       False  xenonpy.compositions  7069          True  python
# 1199       False  xenonpy.compositions  7071          True  python
#
#       maxAbsError  meanAbsError  meanSquareError                     method  \
# 0        4.125291      0.610073         0.870355  pytorch.nn.neural_network
# 1        4.391356      0.572747         0.765702  pytorch.nn.neural_network
# 2        5.243320      0.603243         0.898776  pytorch.nn.neural_network
# 3        4.864137      0.582556         0.830686  pytorch.nn.neural_network
# 4        5.009331      0.621046         0.934543  pytorch.nn.neural_network
# 5        4.293794      0.665161         1.010093  pytorch.nn.neural_network
# 6        4.898829      0.640651         0.961659  pytorch.nn.neural_network
# 7        3.992013      0.550671         0.732546  pytorch.nn.neural_network
# 8        4.784416      0.554728         0.788352  pytorch.nn.neural_network
# 9        4.674271      0.611629         0.875630  pytorch.nn.neural_network
# 10       3.906834      0.580558         0.806119  pytorch.nn.neural_network
# 11      12.428086      0.582455         0.877435  pytorch.nn.neural_network
# 12       4.976136      0.622786         0.904258  pytorch.nn.neural_network
# 13       4.385163      0.614426         0.876923  pytorch.nn.neural_network
# 14       4.076165      0.605333         0.892338  pytorch.nn.neural_network
# 15       4.224774      0.570167         0.797218  pytorch.nn.neural_network
# 16       4.256370      0.604536         0.848831  pytorch.nn.neural_network
# 17       3.793726      0.622188         0.918556  pytorch.nn.neural_network
# 18      13.467704      0.627428         1.019796  pytorch.nn.neural_network
# 19       4.363132      0.561447         0.792104  pytorch.nn.neural_network
# 20       5.200938      0.660836         1.034627  pytorch.nn.neural_network
# 21       4.305627      0.590186         0.828892  pytorch.nn.neural_network
# 22       4.214491      0.587063         0.851162  pytorch.nn.neural_network
# 23      13.011836      0.573683         0.898575  pytorch.nn.neural_network
# 24       4.103242      0.636759         0.926710  pytorch.nn.neural_network
# 25      11.998322      0.595806         0.920895  pytorch.nn.neural_network
# 26       4.962874      0.667842         1.108801  pytorch.nn.neural_network
# 27      13.320510      0.615032         0.985917  pytorch.nn.neural_network
# 28       3.828832      0.613950         0.862349  pytorch.nn.neural_network
# 29       4.736187      0.617181         0.898640  pytorch.nn.neural_network
# ...           ...           ...              ...                        ...
# 1170     3.979739      0.586220         0.810809  pytorch.nn.neural_network
# 1171     4.004586      0.638912         0.971183  pytorch.nn.neural_network
# 1172     4.354493      0.576682         0.796462  pytorch.nn.neural_network
# 1173     4.922834      0.644751         0.978274  pytorch.nn.neural_network
# 1174     4.310754      0.657349         0.996415  pytorch.nn.neural_network
# 1175    13.593245      0.584668         0.901911  pytorch.nn.neural_network
# 1176     4.543819      0.608095         0.848963  pytorch.nn.neural_network
# 1177     4.283495      0.604357         0.882609  pytorch.nn.neural_network
# 1178     4.668386      0.633129         0.955498  pytorch.nn.neural_network
# 1179    14.104414      0.619708         0.982766  pytorch.nn.neural_network
# 1180     4.226579      0.638043         0.969911  pytorch.nn.neural_network
# 1181     4.236075      0.601188         0.855451  pytorch.nn.neural_network
# 1182     4.827918      0.616433         0.902974  pytorch.nn.neural_network
# 1183     4.368040      0.599384         0.852789  pytorch.nn.neural_network
# 1184     4.734838      0.645627         0.986297  pytorch.nn.neural_network
# 1185     4.165689      0.612154         0.860553  pytorch.nn.neural_network
# 1186     4.486676      0.603794         0.884255  pytorch.nn.neural_network
# 1187     4.295313      0.606161         0.847644  pytorch.nn.neural_network
# 1188     4.735138      0.646302         0.991291  pytorch.nn.neural_network
# 1189     4.136850      0.601297         0.853464  pytorch.nn.neural_network
# 1190     4.161761      0.614107         0.851974  pytorch.nn.neural_network
# 1174  inorganic.crystal.band_gap  0.679522             0.998206      0.840578
# 1175  inorganic.crystal.band_gap  0.724290             0.949690      0.862856
# 1176  inorganic.crystal.band_gap  0.742002             0.921392      0.864145
# 1177  inorganic.crystal.band_gap  0.706157             0.939473      0.849389
# 1178  inorganic.crystal.band_gap  0.683146             0.977496      0.844075
# 1179  inorganic.crystal.band_gap  0.685397             0.991346      0.852304
# 1180  inorganic.crystal.band_gap  0.678320             0.984841      0.832640
# 1181  inorganic.crystal.band_gap  0.714178             0.924906      0.853260
# 1182  inorganic.crystal.band_gap  0.711082             0.950249      0.848794
# 1183  inorganic.crystal.band_gap  0.710785             0.923466      0.849527
# 1184  inorganic.crystal.band_gap  0.688535             0.993125      0.840301
# 1185  inorganic.crystal.band_gap  0.716269             0.927660      0.852824
# 1186  inorganic.crystal.band_gap  0.722429             0.940348      0.858202
# 1187  inorganic.crystal.band_gap  0.712065             0.920676      0.841673
# 1188  inorganic.crystal.band_gap  0.685633             0.995636      0.840940
# 1189  inorganic.crystal.band_gap  0.723835             0.923831      0.850182
# 1190  inorganic.crystal.band_gap  0.716874             0.923024      0.847045
# 1191  inorganic.crystal.band_gap  0.705923             0.951999      0.855497
# 1192  inorganic.crystal.band_gap  0.743317             0.904433      0.864016
# 1193  inorganic.crystal.band_gap  0.703174             0.961286      0.859062
# 1194  inorganic.crystal.band_gap  0.678227             0.995395      0.844811
# 1195  inorganic.crystal.band_gap  0.665521             0.987232      0.830033
# 1196  inorganic.crystal.band_gap  0.654642             1.030387      0.836491
# 1197  inorganic.crystal.band_gap  0.692823             0.984958      0.858516
# 1198  inorganic.crystal.band_gap  0.704229             0.938684      0.848857
# 1199  inorganic.crystal.band_gap  0.707268             0.903389      0.846126
#
#       succeed  transferred
# 0        True        False
# 1        True        False
# 2        True        False
# 3        True        False
# 4        True        False
# 5        True        False
# 6        True        False
# 7        True        False
# 8        True        False
# 9        True        False
# 10       True        False
# 11       True        False
# 12       True        False
# 13       True        False
# 14       True        False
# 15       True        False
# 16       True        False
# 17       True        False
# 18       True        False
# 19       True        False
# 20       True        False
# 21       True        False
# 22       True        False
# 23       True        False
# 24       True        False
# 25       True        False
# 26       True        False
# 27       True        False
# 28       True        False
# 29       True        False
# ...       ...          ...
# 1170     True        False
# 1171     True        False
# 1172     True        False
# 1173     True        False
# 1174     True        False
# 1175     True        False
# 1176     True        False
# 1177     True        False
# 1178     True        False
# 1179     True        False
# 1180     True        False
# 1181     True        False
# 1182     True        False
# 1183     True        False
# 1184     True        False
# 1185     True        False
# 1186     True        False
# 1187     True        False
# 1188     True        False
# 1189     True        False
# 1190     True        False
# 1191     True        False
# 1192     True        False
# 1193     True        False
# 1194     True        False
# 1195     True        False
# 1196     True        False
# 1197     True        False
# 1198     True        False
# 1199     True        False
#
# [1200 rows x 18 columns]

# %% [markdown]
# You can use `?` mark under any function's name to show it's docs.

# %%
mdl.upload_model(
    modelset_id=2, 
    describe=dict(
        property='test2',
        descriptor='test2',
        method='test',
        lang='test',
        deprecated=True,
        isRegression=True,
        meanAbsError=1.11,
        pearsonCorr=0.85,
    ),
    training_info=dict(a=1, b=2),
    supplementary=dict(true=[1,2,3,4], pred=[1,2,2,4])
)(file='set1', raw_results=True)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-120-4a463cf06ba2> in <module>
#      13     training_info=dict(a=1, b=2),
#      14     supplementary=dict(true=[1,2,3,4], pred=[1,2,2,4])
# ---> 15 )(file='set1', raw_results=True)
#
# ~/projects/XenonPy/xenonpy/mdl/base.py in __call__(self, file, raw_results, *querying_vars)
#      91
#      92             raise HTTPError('status_code: %s, %s' %
# ---> 93                             (ret.status_code, message))
#      94         ret = ret.json()
#      95         if 'errors' in ret:
#
# HTTPError: status_code: 400, {'errors': [{'message': "Context creation failed: illegal api_key: 'MnGGyUos'", 'extensions': {'code': 'UNAUTHENTICATED'}}]}

# %%
mdl.get_training_env(model_id=1234)()
info = mdl.get_training_info(model_id=1234)()
info.tail(3)
info.plot(y=['train_mse_loss', 'val_mse'])
# Out:
# {'python': '3.7.4 (default, Aug 13 2019, 20:35:49) \n[GCC 7.3.0]',
#  'system': '#60-Ubuntu SMP Tue Jul 2 18:22:20 UTC 2019',
#  'numpy': '1.16.4',
#  'torch': '1.1.0',
#  'xenonpy': '0.4.0.beta4',
#  'device': 'cuda:2',
#  'start': '2019/09/17 20:55:56',
#  'finish': '2019/09/17 21:03:04',
#  'time_elapsed': '5 days, 15:33:23.552799',
#  'author': 'Chang Liu',
#  'email': 'liu.chang@ism.ac.jp',
#  'dataset': 'materials project'}
#      total_iters  i_epoch  i_batch  train_mse_loss   val_mae   val_mse  \
# 694          694       22       23        2.060905  1.098812  2.106717
# 695          695       22       24        2.049812  1.162004  2.331702
# 696          696       22       25        2.156136  1.092442  2.166551
#
#      val_rmse    val_r2  val_pearsonr  val_spearmanr  val_p_value  val_max_ae
# 694  1.451453  0.701376      0.850455       0.847006          0.0   12.112278
# 695  1.526991  0.669485      0.844444       0.839916          0.0   12.192457
# 696  1.471921  0.692895      0.837554       0.828305          0.0   12.244514

# %%
ret = mdl.get_model_url(1234)('id', 'url')
ret
# Out:
#      id                                                url
# 0  1234  http://xenon.ism.ac.jp/mdl/inorganic.crystal.e...

# %%
ret = mdl.pull(ret)
ret
# Out:
# 100%|██████████| 1/1 [00:03<00:00,  3.23s/it]
#      id                                              model
# 0  1234  /Users/liuchang/projects/XenonPy/samples/inorg...

# %%
from xenonpy.model.training import Checker

# %%
checker = Checker(ret.model[0])
checker
# Out:
# <Checker> includes:
# "final_state": /Users/liuchang/projects/XenonPy/samples/inorganic.crystal.efermi/xenonpy.compositions/pytorch.nn.neural_network/290-180-177-162-46-32-1-$WEnkZ6e3/final_state.pth.s
# "training_info": /Users/liuchang/projects/XenonPy/samples/inorganic.crystal.efermi/xenonpy.compositions/pytorch.nn.neural_network/290-180-177-162-46-32-1-$WEnkZ6e3/training_info.pd.xz
# "model_class": /Users/liuchang/projects/XenonPy/samples/inorganic.crystal.efermi/xenonpy.compositions/pytorch.nn.neural_network/290-180-177-162-46-32-1-$WEnkZ6e3/model_class.pkl.z
# "init_state": /Users/liuchang/projects/XenonPy/samples/inorganic.crystal.efermi/xenonpy.compositions/pytorch.nn.neural_network/290-180-177-162-46-32-1-$WEnkZ6e3/init_state.pth.s
# "model": /Users/liuchang/projects/XenonPy/samples/inorganic.crystal.efermi/xenonpy.compositions/pytorch.nn.neural_network/290-180-177-162-46-32-1-$WEnkZ6e3/model.pth.m
# "splitter": /Users/liuchang/projects/XenonPy/samples/inorganic.crystal.efermi/xenonpy.compositions/pytorch.nn.neural_network/290-180-177-162-46-32-1-$WEnkZ6e3/splitter.pkl.z
# "model_structure": /Users/liuchang/projects/XenonPy/samples/inorganic.crystal.efermi/xenonpy.compositions/pytorch.nn.neural_network/290-180-177-162-46-32-1-$WEnkZ6e3/model_structure.pkl.z
# "describe": /Users/liuchang/projects/XenonPy/samples/inorganic.crystal.efermi/xenonpy.compositions/pytorch.nn.neural_network/290-180-177-162-46-32-1-$WEnkZ6e3/describe.pkl.z
# "data_indices": /Users/liuchang/projects/XenonPy/samples/inorganic.crystal.efermi/xenonpy.compositions/pytorch.nn.neural_network/290-180-177-162-46-32-1-$WEnkZ6e3/data_indices.pkl.z
# "model_params": /Users/liuchang/projects/XenonPy/samples/inorganic.crystal.efermi/xenonpy.compositions/pytorch.nn.neural_network/290-180-177-162-46-32-1-$WEnkZ6e3/model_params.pkl.z

# %% [markdown]
# ### model downloading
#
# Maybe you have noticed that the result also has a column named 'url.' As the name means, we can use this information to download models.
# Since HTTP downloading in python is not an easy job for a novice, we also offered a rather simple function to help your downloading.
#
# Assuming we want to download the top 5 best performance models based on their **MAE**. The downloading procedure is straight-forward as below.

# %% [markdown]
# #### 1. sort models by the value of **MAE**

# %%
summary = summary.sort_values('mae')
summary.head(5)
# Out:
#                                                       url  \
# mId
# M23001  http://xenon.ism.ac.jp/mdl/S1/inorganic.crysta...
# M23265  http://xenon.ism.ac.jp/mdl/S1/inorganic.crysta...
# M24137  http://xenon.ism.ac.jp/mdl/S1/inorganic.crysta...
# M23203  http://xenon.ism.ac.jp/mdl/S1/inorganic.crysta...
# M25054  http://xenon.ism.ac.jp/mdl/S1/inorganic.crysta...
#
#                                                  modelSet  \
# mId
# M23001  Stable inorganic compounds in materials projec...
# M23265  Stable inorganic compounds in materials projec...
# M24137  Stable inorganic compounds in materials projec...
# M23203  Stable inorganic compounds in materials projec...
# M25054  Stable inorganic compounds in materials projec...
#
#                         property           descriptor  \
# mId
# M23001  inorganic.crystal.volume  xenonpy.composition
# M23265  inorganic.crystal.volume  xenonpy.composition
# M24137  inorganic.crystal.volume  xenonpy.composition
# M23203  inorganic.crystal.volume  xenonpy.composition
# M25054  inorganic.crystal.volume  xenonpy.composition
#
#                            method    lang  regress  transferred  succeed  \
# mId
# M23001  pytorch.nn.neural_network  python     True        False     True
# M23265  pytorch.nn.neural_network  python     True        False     True
# M24137  pytorch.nn.neural_network  python     True        False     True
# M23203  pytorch.nn.neural_network  python     True        False     True
# M25054  pytorch.nn.neural_network  python     True        False     True
#
#               mae         r
# mId
# M23001  22.565939  0.996093
# M23265  22.759855  0.995420
# M24137  22.883263  0.995601
# M23203  22.954258  0.995931
# M25054  22.983179  0.996287

# %% [markdown]
# #### 2. get the first 5 **url**s

# %%
urls = summary['url'].iloc[:5]
urls
# Out:
# mId
# M23001    http://xenon.ism.ac.jp/mdl/S1/inorganic.crysta...
# M23265    http://xenon.ism.ac.jp/mdl/S1/inorganic.crysta...
# M24137    http://xenon.ism.ac.jp/mdl/S1/inorganic.crysta...
# M23203    http://xenon.ism.ac.jp/mdl/S1/inorganic.crysta...
# M25054    http://xenon.ism.ac.jp/mdl/S1/inorganic.crysta...
# Name: url, dtype: object

# %% [markdown]
# #### 3. download models by using ``mdl.pull`` method

# %%
results = mdl.pull(urls)
# Out:
# 100%|██████████| 5/5 [00:00<00:00,  5.21it/s]

# %% [markdown]
# The result object is a list that contains the local paths where the downloaded models are. You can exactly specify the saving-path by feeding a string of path to the `save_to` parameter of `mdl.pull`.

# %%
results
# Out:
# ['/Users/liuchang/projects/xenonpy/samples/S1/inorganic.crystal.volume/xenonpy.composition/pytorch.nn.neural_network/04cd-290-281-153-75-21@1',
#  '/Users/liuchang/projects/xenonpy/samples/S1/inorganic.crystal.volume/xenonpy.composition/pytorch.nn.neural_network/ajc1-290-261-122-66-25-10@1',
#  '/Users/liuchang/projects/xenonpy/samples/S1/inorganic.crystal.volume/xenonpy.composition/pytorch.nn.neural_network/rzr8-290-285-177-111-58-27@1',
#  '/Users/liuchang/projects/xenonpy/samples/S1/inorganic.crystal.volume/xenonpy.composition/pytorch.nn.neural_network/p0nx-290-285-126-52-22-13@1',
#  '/Users/liuchang/projects/xenonpy/samples/S1/inorganic.crystal.volume/xenonpy.composition/pytorch.nn.neural_network/r4t2-290-243-131-67-23@1']

# %% [markdown]
# Let's see some other models. For example, the `crystal graph CNN` models.

# %%
summary = mdl(
    modelset_has="Stable inorganic compounds",
    descriptor_has='crystal_graph',
)

# %%
summary.head(5)
# Out:
#                                                       url  \
# mId
# M69008  http://xenon.ism.ac.jp/mdl/S1/inorganic.crysta...
# M69009  http://xenon.ism.ac.jp/mdl/S1/inorganic.crysta...
# M69010  http://xenon.ism.ac.jp/mdl/S1/inorganic.crysta...
# M69011  http://xenon.ism.ac.jp/mdl/S1/inorganic.crysta...
# M69012  http://xenon.ism.ac.jp/mdl/S1/inorganic.crysta...
#
#                                                  modelSet  \
# mId
# M69008  Stable inorganic compounds in materials projec...
# M69009  Stable inorganic compounds in materials projec...
# M69010  Stable inorganic compounds in materials projec...
# M69011  Stable inorganic compounds in materials projec...
# M69012  Stable inorganic compounds in materials projec...
#
#                         property                       descriptor  \
# mId
# M69008  inorganic.crystal.efermi  xenonpy.cgcnn.crystal_graph_cnn
# M69009  inorganic.crystal.efermi  xenonpy.cgcnn.crystal_graph_cnn
# M69010  inorganic.crystal.efermi  xenonpy.cgcnn.crystal_graph_cnn
# M69011  inorganic.crystal.efermi  xenonpy.cgcnn.crystal_graph_cnn
# M69012  inorganic.crystal.efermi  xenonpy.cgcnn.crystal_graph_cnn
#
#                            method    lang  regress  transferred  succeed  \
# mId
# M69008  pytorch.nn.neural_network  python     True        False     True
# M69009  pytorch.nn.neural_network  python     True        False     True
# M69010  pytorch.nn.neural_network  python     True        False     True
# M69011  pytorch.nn.neural_network  python     True        False     True
# M69012  pytorch.nn.neural_network  python     True        False     True
#
#              mae         r
# mId
# M69008  0.680264  0.946909
# M69009  0.680264  0.946909
# M69010  0.734605  0.940486
# M69011  0.735575  0.939878
# M69012  0.716477  0.944133

# %%
summary.groupby('property')['r'].max()
# Out:
# property
# inorganic.crystal.band_gap                     0.929118
# inorganic.crystal.density                      0.995538
# inorganic.crystal.efermi                       0.965173
# inorganic.crystal.final_energy_per_atom        0.975265
# inorganic.crystal.formation_energy_per_atom    0.990847
# inorganic.crystal.total_magnetization          0.666429
# inorganic.crystal.volume                       0.601476
# Name: r, dtype: float64

# %% [markdown]
# ### retrieve model

# %% [markdown]
# You can use `xenonpy.model.utils.Checker` to reload the downloaded models. For example, we load the first downloaded model into our notebook.

# %%
# --- import necessary libraries

from xenonpy.model.utils import Checker

# %%
checker = Checker(results[0])

# %% [markdown]
# If successful, use ``checker.trained_model`` to retrieve your model.
#
# **<span style="color: red; ">Warning: checker.trained_model is deprecated, will be removed in v0.5.0</span>**

# %%
checker.trained_model
# Out:
# /usr/local/miniconda3/envs/xepy37/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function trained_model (This property is rotten and will be removed in v0.5.0).
#   """Entry point for launching an IPython kernel.
# /usr/local/miniconda3/envs/xepy37/lib/python3.7/site-packages/torch/serialization.py:454: SourceChangeWarning: source code of class 'torch.nn.modules.container.Sequential' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/miniconda3/envs/xepy37/lib/python3.7/site-packages/torch/serialization.py:454: SourceChangeWarning: source code of class 'torch.nn.modules.linear.Linear' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/miniconda3/envs/xepy37/lib/python3.7/site-packages/torch/serialization.py:454: SourceChangeWarning: source code of class 'torch.nn.modules.batchnorm.BatchNorm1d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/miniconda3/envs/xepy37/lib/python3.7/site-packages/torch/serialization.py:454: SourceChangeWarning: source code of class 'torch.nn.modules.activation.ReLU' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/miniconda3/envs/xepy37/lib/python3.7/site-packages/torch/serialization.py:454: SourceChangeWarning: source code of class 'torch.nn.modules.dropout.Dropout' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# Sequential(
#   (0): Layer1d(
#     (layer): Linear(in_features=290, out_features=281, bias=True)
#     (batch_nor): BatchNorm1d(281, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act_func): ReLU()
#     (dropout): Dropout(p=0.1)
#   )
#   (1): Layer1d(
#     (layer): Linear(in_features=281, out_features=153, bias=True)
#     (batch_nor): BatchNorm1d(153, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act_func): ReLU()
#     (dropout): Dropout(p=0.1)
#   )
#   (2): Layer1d(
#     (layer): Linear(in_features=153, out_features=75, bias=True)
#     (batch_nor): BatchNorm1d(75, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act_func): ReLU()
#     (dropout): Dropout(p=0.1)
#   )
#   (3): Layer1d(
#     (layer): Linear(in_features=75, out_features=21, bias=True)
#     (batch_nor): BatchNorm1d(21, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act_func): ReLU()
#     (dropout): Dropout(p=0.1)
#   )
#   (4): Layer1d(
#     (layer): Linear(in_features=21, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# You can list all the information for a download model by printing the ``checker`` object.

# %%
checker
# Out:
# <Checker> includes:
# "init_model.@1": /Users/liuchang/projects/xenonpy/samples/S1/inorganic.crystal.volume/xenonpy.composition/pytorch.nn.neural_network/04cd-290-281-153-75-21@1/init_model.@1.pkl.z
# "describe.@1": /Users/liuchang/projects/xenonpy/samples/S1/inorganic.crystal.volume/xenonpy.composition/pytorch.nn.neural_network/04cd-290-281-153-75-21@1/describe.@1.pkl.z
# "y_true.@1": /Users/liuchang/projects/xenonpy/samples/S1/inorganic.crystal.volume/xenonpy.composition/pytorch.nn.neural_network/04cd-290-281-153-75-21@1/y_true.@1.pkl.z
# "y_pred.@1": /Users/liuchang/projects/xenonpy/samples/S1/inorganic.crystal.volume/xenonpy.composition/pytorch.nn.neural_network/04cd-290-281-153-75-21@1/y_pred.@1.pkl.z
# "runner.@1": /Users/liuchang/projects/xenonpy/samples/S1/inorganic.crystal.volume/xenonpy.composition/pytorch.nn.neural_network/04cd-290-281-153-75-21@1/runner.@1.pkl.z
# "y_indices.@1": /Users/liuchang/projects/xenonpy/samples/S1/inorganic.crystal.volume/xenonpy.composition/pytorch.nn.neural_network/04cd-290-281-153-75-21@1/y_indices.@1.pkl.z
# "y_true_fit.@1": /Users/liuchang/projects/xenonpy/samples/S1/inorganic.crystal.volume/xenonpy.composition/pytorch.nn.neural_network/04cd-290-281-153-75-21@1/y_true_fit.@1.pkl.z
# "y_scale.@1": /Users/liuchang/projects/xenonpy/samples/S1/inorganic.crystal.volume/xenonpy.composition/pytorch.nn.neural_network/04cd-290-281-153-75-21@1/y_scale.@1.pkl.z
# "scores.@1": /Users/liuchang/projects/xenonpy/samples/S1/inorganic.crystal.volume/xenonpy.composition/pytorch.nn.neural_network/04cd-290-281-153-75-21@1/scores.@1.pkl.z
# "trained_model.@1": /Users/liuchang/projects/xenonpy/samples/S1/inorganic.crystal.volume/xenonpy.composition/pytorch.nn.neural_network/04cd-290-281-153-75-21@1/trained_model.@1.pkl.z
# "x_indices.@1": /Users/liuchang/projects/xenonpy/samples/S1/inorganic.crystal.volume/xenonpy.composition/pytorch.nn.neural_network/04cd-290-281-153-75-21@1/x_indices.@1.pkl.z
# "x_scale.@1": /Users/liuchang/projects/xenonpy/samples/S1/inorganic.crystal.volume/xenonpy.composition/pytorch.nn.neural_network/04cd-290-281-153-75-21@1/x_scale.@1.pkl.z
# "y_pred_fit.@1": /Users/liuchang/projects/xenonpy/samples/S1/inorganic.crystal.volume/xenonpy.composition/pytorch.nn.neural_network/04cd-290-281-153-75-21@1/y_pred_fit.@1.pkl.z

# %% [markdown]
# You can use ``checker[<file name withour extension>]`` to load any data under the model dir. An example is below:

# %%
checker['scores.@1']
# Out:
# {'mae': 22.565939,
#  'rmse': 46.829636,
#  'r2': 0.991713183810694,
#  'pearsonr': 0.9960926,
#  'spearmanr': 0.9976251253835112,
#  'p_value': 0.0}

# %% [markdown]
# ### download R model
#
# There are also a lot of R models in **XenonPy.MDL**, download them is exactly the same works like we did above. Just use ``lang_has='r'`` when querying.

# %%
from xenonpy.datatools import MDL

mdl = MDL()

summary = mdl(
    modelset_has="QM9",  # sub string in the name of modelset
    property_has="hartree", # substring for property name
    lang_has='r',
)

# %%
summary.head(3)
# Out:
#                                                       url  \
# mId
# M18001  http://xenon.ism.ac.jp/mdl/S3/organic.nonpolym...
# M18002  http://xenon.ism.ac.jp/mdl/S3/organic.nonpolym...
# M18003  http://xenon.ism.ac.jp/mdl/S3/organic.nonpolym...
#
#                                         modelSet  \
# mId
# M18001  QM9 Dataset from Quantum-Machine project
# M18002  QM9 Dataset from Quantum-Machine project
# M18003  QM9 Dataset from Quantum-Machine project
#
#                             property           descriptor  \
# mId
# M18001  organic.nonpolymer.g_hartree  rcdk.fp.fingerprint
# M18002  organic.nonpolymer.g_hartree  rcdk.fp.fingerprint
# M18003  organic.nonpolymer.g_hartree  rcdk.fp.fingerprint
#
#                          method lang  regress  transferred  succeed      mae  \
# mId
# M18001  mxnet.nn.neural_network    r     True        False     True  15.8705
# M18002  mxnet.nn.neural_network    r     True        False     True  19.7939
# M18003  mxnet.nn.neural_network    r     True        False     True  14.9261
#
#              r
# mId
# M18001  0.8282
# M18002  0.7890
# M18003  0.8510

# %%
urls = summary['url'].iloc[:3]
results = mdl.pull(urls)
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 20.92it/s]

# %%
results
# Out:
# ['/Users/liuchang/projects/xenonpy/samples/S3/organic.nonpolymer.g_hartree/rcdk.fp.fingerprint/mxnet.nn.neural_network/shotgun_G_Hartree_randFP1021_corr-0.8282_mxnet_400-81-10-1_2018-04-20',
#  '/Users/liuchang/projects/xenonpy/samples/S3/organic.nonpolymer.g_hartree/rcdk.fp.fingerprint/mxnet.nn.neural_network/shotgun_G_Hartree_randFP1026_corr-0.789_mxnet_266-127-94-10-1_2018-04-20',
#  '/Users/liuchang/projects/xenonpy/samples/S3/organic.nonpolymer.g_hartree/rcdk.fp.fingerprint/mxnet.nn.neural_network/shotgun_G_Hartree_randFP1033_corr-0.851_mxnet_150-65-21-1_2018-04-20']

# %% [markdown]
# **R tutorials will be released later.**
